# %% [markdown]
# # Responses to MusicLab via Nettskjema API

# %%
import requests
import json
import zipfile
import socket
import os
import base64
import time
import pandas as pd

# %% [markdown]
# navigate to the directory storing your *nettskjema_token.txt* file

# %%
os.listdir()
# Out:
# ['PullingMusicLab.ipynb',
#  '.DS_Store',
#  'PullingNettskjema.ipynb',
#  'README.md',
#  '.gitignore',
#  'copen_netts.tsv',
#  'Test_API',
#  '.ipynb_checkpoints',
#  '.git',
#  'nettskjema_token.txt']

# %%
f=open('nettskjema_token.txt','r')
TOKEN = f.read()
f.close()

# %%
session = requests.Session()
session.headers.update({'Authorization': 'Bearer ' + TOKEN})

# %% [markdown]
# Test the token by sending a request to see its expiration date.

# %%
# confirm the token is working on this IP with the check on expiry date
request_url = "https://nettskjema.no/api/v2/users/admin/tokens/expire-date"
response = session.get(request_url)
response.content
# Out:
# b'{"expireDate":"2022-10-18T17:38:29.000+0200"}'

# %% [markdown]
# # Gathering Musiclab phone sensor data

# %%
# get metadata on submissions for the music lab app

formID = 141510
submissionID = 16561653
request_url = 'https://nettskjema.no/api/v2/forms/' + str(formID) + '/submissions?fromSubmissionId=' + str(submissionID)
response = session.get(request_url)
subIDs = json.loads(response.content.decode())
print('Submissions since subID ' + str(submissionID) + ': ' + str(len(subIDs)))
if len(subIDs)<5: # print error message or top responses 
    print(subIDs)
else:
    print(subIDs[0])
# Out:
# Submissions since subID 16561653: 23503
# {'submissionId': 16767882, 'createdDate': '2021-10-29T08:40:57.000+0200', 'modifiedDate': '2021-10-29T08:40:57.000+0200', 'delivered': True, 'answerTime': 0, 'answers': [{'answerId': 103133021, 'questionId': 1996787, 'textAnswer': 'cfcd73d7-4af9-08e2-aa6a-e73e87bbfbf3'}, {'answerId': 103133022, 'questionId': 1996788, 'textAnswer': 'data.zip', 'attachments': [{'answerAttachmentId': 302365, 'fileName': 'data.zip', 'mediaType': 'application/zip'}]}]}

# %% [markdown]
# test one submission data

# %%
subn = 0
print('submissionID : ' + str(subIDs[subn]['submissionId']))
for subm in subIDs[subn]['answers']:
    if len(subm)<4:
        devID = subm['textAnswer']
        print('Submitting instillation: ' + devID)
    else:
        att_dets = subm['attachments'][0] # the app only attaches one zipped file called data.zip
        print(att_dets)
# Out:
# submissionID : 16767882
# Submitting instillation: cfcd73d7-4af9-08e2-aa6a-e73e87bbfbf3
# {'answerAttachmentId': 302365, 'fileName': 'data.zip', 'mediaType': 'application/zip'}

# %% [markdown]
# so to call the attachment for that submission we use the request:

# %%
subn = 0 # just calling one as an example

subID = str(subIDs[subn]['submissionId'])
attID = str(att_dets['answerAttachmentId'])
request_url = 'https://nettskjema.no/api/v2/submissions/' + subID + '/attachments/' + attID
response = session.get(request_url)

att_dets = json.loads(response.content.decode())
print(att_dets)
# Out:
# {'fileName': 'data.zip', 'fileSize': 10637, 'mediaType': 'application/zip', 'content': '...'}

# %% [markdown]
# The nettskjema API returns attachments as encoded zipfiles in byte strings. To make these readable, we need to decode then save the string as a zip file and then unzip them. Thankfully there are python libraries for this.
#
# First be sure you are in a suitable local folder, then unpack the attachement.

# %%
os.mkdir('./Copendata')
os.chdir('Copendata')

# %%
subn = 0 # just calling one as an example

subID = str(subIDs[subn]['submissionId'])
attID = str(subIDs[subn]['answers'][0]['attachments'][0]['answerAttachmentId'])
request_url = 'https://nettskjema.no/api/v2/submissions/' + subID + '/attachments/' + attID
response = session.get(request_url)

att_dets = json.loads(response.content.decode())

# write the decoded attachment into a zip file
f=open('data.zip', 'wb')
f.write(base64.b64decode(att_dets['content']))
f.close()

# and then unzip that file, leaving a uniquely titled csv, I hope
with zipfile.ZipFile('data.zip', 'r') as zip_ref:
    if not os.path.exists(str(subID)):
        os.mkdir(str(subID))
        zip_ref.extractall('./'+str(subID)) # Not unique filenames so use the unique submission IDs 

print(os.listdir())
os.chdir('./'+str(subID))
print(os.listdir())
os.chdir('..')
# Out:
# ['data.zip', '16767882']
# ['cfcd73d7-4af9-08e2-aa6a-e73e87bbfbf3.deviceMotion.csv']

# %% [markdown]
# Here we have a minute recording from a device with the unique installation ID 'cfcd73d7-4a...' in a format that is easy to read.

# %% [markdown]
# The files within the zip are named for the device and information type, but do not include the submission number. This means if they are opened into a folder that already contains a previous recording from the same device, the previously saved recording will be overwritten and lost. To avoid this, the files are unzipped within a folder names for that unique submission.
#
# Now to collect many at once:

# %%
# pull in the data files and unpack them

newSubs = 0 # count the submission sampled
tic = time.time()
for submis in subIDs[:10]: # just getting 10 as a test
    # first find out the attachment file ID for this submission
    subID = str(submis['submissionId'])
    # if there is an IDed attachment for this submission, get the file
    for subm in submis['answers']:
        if len(subm)>3:
            attID = str(subm['attachments'][0]['answerAttachmentId'])
            request_url = 'https://nettskjema.no/api/v2/submissions/' + subID + '/attachments/' + attID
            response = session.get(request_url)
            newSubs += 1
            att_dets = json.loads(response.content.decode())
            # write the decoded attachment into a zip file
            f=open('data.zip', 'wb')
            f.write(base64.b64decode(att_dets['content']))
            f.close()
            # and then unzip that file, leaving a uniquely titled csv, I hope
            with zipfile.ZipFile('data.zip', 'r') as zip_ref:
                if not os.path.exists(str(subID)):
                    os.mkdir(str(subID))
                    zip_ref.extractall('./'+str(subID)) # if not unique can use the unique submission IDs 

print('time to collect ' + str(newSubs) + ' attachments: ' + str(time.time() - tic))
# Out:
# time to collect 10 attachments: 0.8018779754638672

# %%
#os.chdir('nettskjemaData')
os.chdir('CopenData')

# %%
subs_already  = os.listdir()#.sort()
subs_already.sort()
print(len(subs_already))
lastsub = '16609378' #subs_already[-2]
lastsub 
# 16550625
# Out:
# 2274
# '16609378'

# %%
# collect submission IDs to form from a specific date
#form_ID = 141510
#submissions_ID_range = 'https://nettskjema.no/api/v2/forms/' + str(form_ID) + '/submissions?fields=submissionId&fromSubmissionId=' + lastsub
submissions_ID_range = 'https://nettskjema.no/api/v2/forms/141510/submissions?fields=submissionId&fromDate=2021-10-25T13%3A43%3A17.486%2B0100'

response = session.get(submissions_ID_range)
subIDs = json.loads(response.content.decode())#eval(response.content.decode())
print(len(subIDs))
if len(subIDs)<5:
    print(subIDs)
else:
    print(subIDs[0])
    
#1976
# {'submissionId': 16609378}
# Out:
# 354
# {'submissionId': 16638490}

# %%
# pull in all the data as fast as possible.
submission_dets = 'https://nettskjema.no/api/v2/submissions/'
newSubs = 0
tic = time.time()
for subm in subIDs[1000:]:
    # first find out the attachment file ID for this submission
    subid = subm["submissionId"]
    response = session.get(submission_dets + str(subid) + '/attachments')
    sub_atts = json.loads(response.content.decode())
    # if there is an IDed attachment for this submission, get the file
    if len(sub_atts)>0:
        attid = sub_atts[0]
        newSubs += 1
        response = session.get(submission_dets + str(subid) + '/attachments/' + str(attid))
        att_dets = json.loads(response.content.decode())
        # write the decoded attachment into a zip file
        f=open('data.zip', 'wb')
        f.write(base64.b64decode(att_dets['content']))
        f.close()
        # and then unzip that file, leaving a uniquely titled csv, I hope
        with zipfile.ZipFile('data.zip', 'r') as zip_ref:
            if not os.path.exists(str(subid)):
                os.mkdir(str(subid))
                zip_ref.extractall('./'+str(subid)) # if not unique can use the unique submission IDs 
print(time.time() - tic)
print(newSubs)
# Out:
# 4047.5774102211
# 22503

# %% [markdown]
# for subid in folders:
#     if subid.startswith('1'):
#         filenames = os.listdir('./CopenData/'+str(subid))
#         print(filenames)
#         for fn in filenames:
#             if fn.endswith('.csv'):
#                 print(fn)
#
#                 sourcefile = './CopenData/'+str(subid) + '/' + fn
#                 targetfile = './CompressedData/'+str(subid) + '.' + fn
#                 print(targetfile)
#                 os.rename(sourcefile,targetfile)

# %%
# one option is to pack a batch into a single folder, 
# files renamed with the combo of installation number and submission ID
#

# %% [markdown]
# # Check out other forms

# %%
formes = [141510,225781,225357,225336,225387,225707,225692,225713,225713,225702,225709,225693,225714,225695,225711]

# %%
formID = formes[4]
request_url = 'https://nettskjema.no/api/v2/forms/' + str(formID)
response = session.get(request_url) # using the request session call which includes the saved API token
form_metadata = json.loads(response.content.decode()) # inteprete recieved string into a python native datatype
form_metadata # show the information output
# Out:
# {'formId': 225387,
#  'languageCode': 'en',
#  'title': '2 After Beethoven (English) MusicLab Copenhagen ',
#  'deliveryDestination': 'DATABASE',
#  'formType': 'DEFAULT',
#  'theme': 'DEFAULT',
#  'createdBy': {'personId': 616293,
#   'username': 'danasw@uio.no',
#   'fullName': 'Dana Swarbrick',
#   'name': 'Dana Swarbrick',
#   'type': 'LOCAL'},
#  'modifiedBy': {'personId': 1676908,
#   'username': 'finnu@uio.no',
#   'fullName': 'Finn Upham',
#   'name': 'Finn Upham',
#   'type': 'LOCAL'},
#  'createdDate': '2021-10-20T10:27:02.000+0200',
#  'modifiedDate': '2021-10-29T09:35:14.000+0200',
#  'openFrom': '2021-10-20T17:40:44.000+0200',
#  'respondentGroup': 'ALL',
#  'editorsContactEmail': 'danasw@uio.no',
#  'editorsSubmissionEmailType': 'NONE',
#  'editors': [{'personId': 573969,
#    'username': 'kaylab@uio.no',
#    'fullName': 'Kayla Burnim',
#    'name': 'Kayla Burnim',
#    'type': 'LOCAL'},
#   {'personId': 1914058,
#    'username': 'finnu1@api',
#    'fullName': 'finn ritmo access',
#    'name': 'finn ritmo access',
#    'type': 'API'},
#   {'personId': 1676908,
#    'username': 'finnu@uio.no',
#    'fullName': 'Finn Upham',
#    'name': 'Finn Upham',
#    'type': 'LOCAL'},
#   {'personId': 616293,
#    'username': 'danasw@uio.no',
#    'fullName': 'Dana Swarbrick',
#    'name': 'Dana Swarbrick',
#    'type': 'LOCAL'}],
#  'collectsPersonalData': False,
#  'maxSubmissionsPerson': 1,
#  'retainRespondentAccessAfterDelivery': False,
#  'clientPostponable': False,
#  'scoreResultDisplayType': 'NONE',
#  'sensitivePersonalDataCollected': False,
#  'codebookActivated': False,
#  'shouldHideProgressBar': False,
#  'shouldPreventDataManipulation': False,
#  'shouldGetRespondentInfoFromPerson': False,
#  'elements': [{'elementId': 3484547,
#    'elementType': 'QUESTION',
#    'sequence': 1,
#    'questions': [{'questionId': 3740343,
#      'sequence': 1,
#      'elementType': 'QUESTION',
#      'mandatory': False,
#      'text': 'userID',
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3479334,
#    'elementType': 'TEXT',
#    'sequence': 2,
#    'description': '<p><em><span style="font-family:&#39;arial&#39; , sans-serif">Please indicate whether you experienced any of the following sensations, feelings, or actions, and if so, to what extent:\xa0</span></em></p>\n\n<p></p>\n'},
#   {'elementId': 3479777,
#    'elementType': 'RADIO',
#    'sequence': 3,
#    'questions': [{'questionId': 3734711,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'Tears.',
#      'answerOptions': [{'answerOptionId': 8625719,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625720,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625721,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625722,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625723,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625724,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625725,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3479778,
#    'elementType': 'RADIO',
#    'sequence': 4,
#    'questions': [{'questionId': 3734712,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'Chills or shivers.',
#      'answerOptions': [{'answerOptionId': 8625726,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625727,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625728,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625729,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625730,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625731,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625732,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3479779,
#    'elementType': 'RADIO',
#    'sequence': 5,
#    'questions': [{'questionId': 3734713,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'A warm feeling in the center of the chest.',
#      'answerOptions': [{'answerOptionId': 8625733,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625734,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625735,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625736,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625737,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625738,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625739,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3479780,
#    'elementType': 'RADIO',
#    'sequence': 6,
#    'questions': [{'questionId': 3734714,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'Choked up.',
#      'answerOptions': [{'answerOptionId': 8625740,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625741,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625742,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625743,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625744,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625745,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625746,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3479781,
#    'elementType': 'RADIO',
#    'sequence': 7,
#    'questions': [{'questionId': 3734715,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'Refreshed, energized, or exhilarated.',
#      'answerOptions': [{'answerOptionId': 8625747,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625748,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625749,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625750,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625751,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625752,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625753,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3479782,
#    'elementType': 'TEXT',
#    'sequence': 8,
#    'description': '<p>Please rate to what extent each of the following statements are true:</p>\n\n<p>I felt/I observed…</p>\n\n<div></div>\n\n<p></p>\n'},
#   {'elementId': 3479783,
#    'elementType': 'RADIO',
#    'sequence': 9,
#    'questions': [{'questionId': 3734716,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'An extraordinary feeling of welcoming or being welcomed.',
#      'answerOptions': [{'answerOptionId': 8625754,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625755,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625756,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625757,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625758,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625759,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625760,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3479784,
#    'elementType': 'RADIO',
#    'sequence': 10,
#    'questions': [{'questionId': 3734717,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'An exceptional sense of closeness appear.',
#      'answerOptions': [{'answerOptionId': 8625761,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625762,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625763,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625764,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625765,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625766,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625767,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3479785,
#    'elementType': 'TEXT',
#    'sequence': 11,
#    'description': '<p><span style="font-weight:normal"><em>Please rate to what extent the following statements are true:</em></span></p>\n\n<p></p>\n'},
#   {'elementId': 3479786,
#    'elementType': 'RADIO',
#    'sequence': 12,
#    'questions': [{'questionId': 3734718,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'I had positive feelings.',
#      'answerOptions': [{'answerOptionId': 8625768,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625769,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625770,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625771,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625772,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625773,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625774,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3479787,
#    'elementType': 'RADIO',
#    'sequence': 13,
#    'questions': [{'questionId': 3734719,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'I had negative feelings.',
#      'answerOptions': [{'answerOptionId': 8625775,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625776,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625777,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625778,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625779,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625780,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625781,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3479788,
#    'elementType': 'RADIO',
#    'sequence': 14,
#    'questions': [{'questionId': 3734720,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'I was tense.',
#      'answerOptions': [{'answerOptionId': 8625782,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625783,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625784,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625785,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625786,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625787,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625788,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3479789,
#    'elementType': 'RADIO',
#    'sequence': 15,
#    'questions': [{'questionId': 3734721,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'I was relaxed.',
#      'answerOptions': [{'answerOptionId': 8625789,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625790,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625791,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625792,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625793,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625794,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625795,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3479790,
#    'elementType': 'RADIO',
#    'sequence': 16,
#    'questions': [{'questionId': 3734722,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'I felt completely alone.',
#      'answerOptions': [{'answerOptionId': 8625796,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625797,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625798,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625799,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625800,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625801,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625802,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3479791,
#    'elementType': 'RADIO',
#    'sequence': 17,
#    'questions': [{'questionId': 3734723,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'I was untouched and indifferent.',
#      'answerOptions': [{'answerOptionId': 8625803,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625804,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625805,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625806,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625807,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625808,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625809,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3479792,
#    'elementType': 'TEXT',
#    'sequence': 18,
#    'description': '<p><em><span style="font-family:&#39;arial&#39; , sans-serif">Please indicate whether each of the following was true, and if so, to what extent:</span></em></p>\n\n<p></p>\n'},
#   {'elementId': 3479793,
#    'elementType': 'RADIO',
#    'sequence': 19,
#    'questions': [{'questionId': 3734724,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'I was moved.',
#      'answerOptions': [{'answerOptionId': 8625810,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625811,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625812,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625813,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625814,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625815,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625816,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3479794,
#    'elementType': 'RADIO',
#    'sequence': 20,
#    'questions': [{'questionId': 3734725,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'I was touched.',
#      'answerOptions': [{'answerOptionId': 8625817,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625818,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625819,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625820,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625821,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625822,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625823,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3479795,
#    'elementType': 'RADIO',
#    'sequence': 21,
#    'questions': [{'questionId': 3734726,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'I was full of admiration and wonder.',
#      'answerOptions': [{'answerOptionId': 8625824,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625825,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625826,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625827,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625828,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625829,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8625830,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3479796,
#    'elementType': 'TEXT',
#    'sequence': 22,
#    'description': '<p><span style="font-family:&#39;calibri&#39; , sans-serif;font-size:14.6667px;font-style:normal;font-weight:400;white-space:pre-wrap">Please rate the extent to which you agree with the </span><span style="font-family:&#39;calibri&#39; , sans-serif;font-size:14.6667px;font-style:normal;font-weight:400;white-space:pre-wrap">following statements:</span></p>\n'},
#   {'elementId': 3483958,
#    'elementType': 'RADIO',
#    'sequence': 23,
#    'questions': [{'questionId': 3739803,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'I felt that I was in the presence of something grand.',
#      'answerOptions': [{'answerOptionId': 8634626,
#        'sequence': 1,
#        'text': '1 (Strongly Disagree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634627,
#        'sequence': 2,
#        'text': '2 (Moderately Disagree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634628,
#        'sequence': 3,
#        'text': '3 (Somewhat Disagree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634629,
#        'sequence': 4,
#        'text': '4 (Neutral)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634630,
#        'sequence': 5,
#        'text': '5 (Somewhat Agree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634631,
#        'sequence': 6,
#        'text': '6 (Moderately Agree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634632,
#        'sequence': 7,
#        'text': '7 (Strongly Agree)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3483959,
#    'elementType': 'RADIO',
#    'sequence': 24,
#    'questions': [{'questionId': 3739804,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'I experienced something greater than myself.',
#      'answerOptions': [{'answerOptionId': 8634633,
#        'sequence': 1,
#        'text': '1 (Strongly Disagree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634634,
#        'sequence': 2,
#        'text': '2 (Moderately Disagree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634635,
#        'sequence': 3,
#        'text': '3 (Somewhat Disagree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634636,
#        'sequence': 4,
#        'text': '4 (Neutral)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634637,
#        'sequence': 5,
#        'text': '5 (Somewhat Agree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634638,
#        'sequence': 6,
#        'text': '6 (Moderately Agree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634639,
#        'sequence': 7,
#        'text': '7 (Strongly Agree)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3483960,
#    'elementType': 'RADIO',
#    'sequence': 25,
#    'questions': [{'questionId': 3739805,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'I felt my jaw drop.',
#      'answerOptions': [{'answerOptionId': 8634640,
#        'sequence': 1,
#        'text': '1 (Strongly Disagree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634641,
#        'sequence': 2,
#        'text': '2 (Moderately Disagree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634642,
#        'sequence': 3,
#        'text': '3 (Somewhat Disagree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634643,
#        'sequence': 4,
#        'text': '4 (Neutral)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634644,
#        'sequence': 5,
#        'text': '5 (Somewhat Agree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634645,
#        'sequence': 6,
#        'text': '6 (Moderately Agree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634646,
#        'sequence': 7,
#        'text': '7 (Strongly Agree)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3483961,
#    'elementType': 'RADIO',
#    'sequence': 26,
#    'questions': [{'questionId': 3739806,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'I gasped.',
#      'answerOptions': [{'answerOptionId': 8634647,
#        'sequence': 1,
#        'text': '1 (Strongly Disagree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634648,
#        'sequence': 2,
#        'text': '2 (Moderately Disagree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634649,
#        'sequence': 3,
#        'text': '3 (Somewhat Disagree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634650,
#        'sequence': 4,
#        'text': '4 (Neutral)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634651,
#        'sequence': 5,
#        'text': '5 (Somewhat Agree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634652,
#        'sequence': 6,
#        'text': '6 (Moderately Agree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634653,
#        'sequence': 7,
#        'text': '7 (Strongly Agree)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3483962,
#    'elementType': 'RADIO',
#    'sequence': 27,
#    'questions': [{'questionId': 3739807,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'I felt challenged to mentally process what I was experiencing.',
#      'answerOptions': [{'answerOptionId': 8634654,
#        'sequence': 1,
#        'text': '1 (Strongly Disagree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634655,
#        'sequence': 2,
#        'text': '2 (Moderately Disagree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634656,
#        'sequence': 3,
#        'text': '3 (Somewhat Disagree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634657,
#        'sequence': 4,
#        'text': '4 (Neutral)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634658,
#        'sequence': 5,
#        'text': '5 (Somewhat Agree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634659,
#        'sequence': 6,
#        'text': '6 (Moderately Agree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634660,
#        'sequence': 7,
#        'text': '7 (Strongly Agree)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3483963,
#    'elementType': 'RADIO',
#    'sequence': 28,
#    'questions': [{'questionId': 3739808,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'I found it hard to comprehend the experience in full.',
#      'answerOptions': [{'answerOptionId': 8634661,
#        'sequence': 1,
#        'text': '1 (Strongly Disagree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634662,
#        'sequence': 2,
#        'text': '2 (Moderately Disagree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634663,
#        'sequence': 3,
#        'text': '3 (Somewhat Disagree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634664,
#        'sequence': 4,
#        'text': '4 (Neutral)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634665,
#        'sequence': 5,
#        'text': '5 (Somewhat Agree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634666,
#        'sequence': 6,
#        'text': '6 (Moderately Agree)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634667,
#        'sequence': 7,
#        'text': '7 (Strongly Agree)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3483964,
#    'elementType': 'TEXT',
#    'sequence': 29,
#    'description': '<p>Answer the following questions.</p>\n\n<p></p>\n'},
#   {'elementId': 3483965,
#    'elementType': 'RADIO',
#    'sequence': 30,
#    'questions': [{'questionId': 3739809,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'To what extent do you believe audience members around you were moved?',
#      'answerOptions': [{'answerOptionId': 8634668,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634669,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634670,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634671,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634672,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634673,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634674,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3483966,
#    'elementType': 'RADIO',
#    'sequence': 31,
#    'questions': [{'questionId': 3739810,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'To what extent did you feel connected to the musicians?',
#      'answerOptions': [{'answerOptionId': 8634675,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634676,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634677,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634678,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634679,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634680,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634681,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3483967,
#    'elementType': 'RADIO',
#    'sequence': 32,
#    'questions': [{'questionId': 3739811,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'To what extent did you feel connected to the other audience members who were also streaming?',
#      'answerOptions': [{'answerOptionId': 8634682,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634683,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634684,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634685,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634686,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634687,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634688,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3483968,
#    'elementType': 'RADIO',
#    'sequence': 33,
#    'questions': [{'questionId': 3739812,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'To what extent did you feel connected to the audience members who were physically attending the concert?',
#      'answerOptions': [{'answerOptionId': 8634689,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634690,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634691,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634692,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634693,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634694,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634695,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3483969,
#    'elementType': 'RADIO',
#    'sequence': 34,
#    'questions': [{'questionId': 3739813,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'How much did you enjoy the piece?',
#      'answerOptions': [{'answerOptionId': 8634696,
#        'sequence': 1,
#        'text': '0 (I didn’t enjoy it at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634697,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634698,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634699,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634700,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634701,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8634702,
#        'sequence': 7,
#        'text': '6 (I enjoyed it very much)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3484209,
#    'elementType': 'RADIO',
#    'sequence': 35,
#    'questions': [{'questionId': 3740037,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'Were you familiar with the music that you heard?',
#      'answerOptions': [{'answerOptionId': 8635138,
#        'sequence': 1,
#        'text': '0 (I have never heard it before)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635139,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635140,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635141,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635142,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635143,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635144,
#        'sequence': 7,
#        'text': '6 (I am very familiar with the music)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3484210,
#    'elementType': 'RADIO',
#    'sequence': 36,
#    'questions': [{'questionId': 3740038,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'To what extent were you absorbed in your own world?',
#      'answerOptions': [{'answerOptionId': 8635145,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635146,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635147,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635148,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635149,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635150,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635151,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3484211,
#    'elementType': 'RADIO',
#    'sequence': 37,
#    'questions': [{'questionId': 3740039,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'To what extent were you absorbed by the music?',
#      'answerOptions': [{'answerOptionId': 8635152,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635153,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635154,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635155,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635156,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635157,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635158,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3484212,
#    'elementType': 'RADIO',
#    'sequence': 38,
#    'questions': [{'questionId': 3740040,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'To what extent did you daydream?',
#      'answerOptions': [{'answerOptionId': 8635159,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635160,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635161,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635162,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635163,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635164,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635165,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3484213,
#    'elementType': 'RADIO',
#    'sequence': 39,
#    'questions': [{'questionId': 3740041,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'To what extent did you lose your sense of time?',
#      'answerOptions': [{'answerOptionId': 8635166,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635167,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635168,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635169,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635170,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635171,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635172,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3484214,
#    'elementType': 'RADIO',
#    'sequence': 40,
#    'questions': [{'questionId': 3740042,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'To what extent were you distracted by thoughts or worries of a personal nature?',
#      'answerOptions': [{'answerOptionId': 8635173,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635174,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635175,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635176,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635177,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635178,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635179,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3484215,
#    'elementType': 'RADIO',
#    'sequence': 41,
#    'questions': [{'questionId': 3740043,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'To what extent were you attentive to the music without distracting thoughts, memories or fantasies?',
#      'answerOptions': [{'answerOptionId': 8635180,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635181,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635182,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635183,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635184,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635185,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635186,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3484216,
#    'elementType': 'RADIO',
#    'sequence': 42,
#    'questions': [{'questionId': 3740044,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'To what extent did you pay attention to other audience members?',
#      'answerOptions': [{'answerOptionId': 8635187,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635188,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635189,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635190,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635191,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635192,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635193,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3484217,
#    'elementType': 'RADIO',
#    'sequence': 43,
#    'questions': [{'questionId': 3740045,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'To what extent did you pay attention to yourself and your physical sensations?',
#      'answerOptions': [{'answerOptionId': 8635194,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635195,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635196,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635197,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635198,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635199,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635200,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3484218,
#    'elementType': 'RADIO',
#    'sequence': 44,
#    'questions': [{'questionId': 3740046,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'To what extent do you feel positively transformed by the music?',
#      'answerOptions': [{'answerOptionId': 8635201,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635202,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635203,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635204,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635205,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635206,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635207,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3484219,
#    'elementType': 'RADIO',
#    'sequence': 45,
#    'questions': [{'questionId': 3740047,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'To what extent do you feel negatively transformed by the music?',
#      'answerOptions': [{'answerOptionId': 8635208,
#        'sequence': 1,
#        'text': '0 (Not at all)',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635209,
#        'sequence': 2,
#        'text': '1',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635210,
#        'sequence': 3,
#        'text': '2',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635211,
#        'sequence': 4,
#        'text': '3',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635212,
#        'sequence': 5,
#        'text': '4',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635213,
#        'sequence': 6,
#        'text': '5',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635214,
#        'sequence': 7,
#        'text': '6 (a lot)',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3484220,
#    'elementType': 'RADIO',
#    'sequence': 46,
#    'questions': [{'questionId': 3740048,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'Were you aware of your physical body during this piece?',
#      'answerOptions': [{'answerOptionId': 8635215,
#        'sequence': 1,
#        'text': 'Not at all',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635216,
#        'sequence': 2,
#        'text': 'Rarely',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635217,
#        'sequence': 3,
#        'text': 'Intermittently',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635218,
#        'sequence': 4,
#        'text': 'Continuously',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3484221,
#    'elementType': 'RADIO',
#    'sequence': 47,
#    'questions': [{'questionId': 3740049,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'Were you aware of your own physical movement during this piece? If so, how much did you move relative to your own usual behaviour at this kind of concert?',
#      'answerOptions': [{'answerOptionId': 8635219,
#        'sequence': 1,
#        'text': 'Not aware of movement',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635220,
#        'sequence': 2,
#        'text': 'Yes and I moved less than usual',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635221,
#        'sequence': 3,
#        'text': 'Yes and I moved a normal amount',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635222,
#        'sequence': 4,
#        'text': 'Yes and I moved more than usual',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]},
#   {'elementId': 3484222,
#    'elementType': 'RADIO',
#    'sequence': 48,
#    'questions': [{'questionId': 3740050,
#      'sequence': 1,
#      'elementType': 'RADIO',
#      'mandatory': False,
#      'text': 'Were you aware of others in the audience moving during the piece? If so, how much were they moving relative to the usual behaviour you observe at this kind of concert?',
#      'answerOptions': [{'answerOptionId': 8635223,
#        'sequence': 1,
#        'text': 'Not aware of others&#39; movement',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635224,
#        'sequence': 2,
#        'text': 'Yes and they moved less than usual',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635225,
#        'sequence': 3,
#        'text': 'Yes and they moved a normal amount',
#        'preselected': False,
#        'correct': False},
#       {'answerOptionId': 8635226,
#        'sequence': 4,
#        'text': 'Yes and they moved more than usual',
#        'preselected': False,
#        'correct': False}],
#      'sendAdditionalRecipientEmail': False,
#      'horizontal': False,
#      'rangeMarksShown': False}]}],
#  'newDesignEnabledSetting': 'ALWAYS',
#  'open': True,
#  'possibleToHaveInvitations': False,
#  'sendingReceiptToRespondent': False}

# %%
elem = form_metadata['elements']

for m in elem:
    print(str(m['elementId']) + ' ' + m['elementType'])
    if 'questions' in m: 
        for q in m['questions']:
            print('\t Qid: ' + str(q['questionId']))
            print('\t Q: ' + str(q['text']))
            if 'answerOptions' in q:
                for a in q['answerOptions']:
                    print('\t \t' + a['text'])
# Out:
# 3484547 QUESTION
# 	 Qid: 3740343
# 	 Q: userID
# 3479334 TEXT
# 3479777 RADIO
# 	 Qid: 3734711
# 	 Q: Tears.
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3479778 RADIO
# 	 Qid: 3734712
# 	 Q: Chills or shivers.
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3479779 RADIO
# 	 Qid: 3734713
# 	 Q: A warm feeling in the center of the chest.
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3479780 RADIO
# 	 Qid: 3734714
# 	 Q: Choked up.
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3479781 RADIO
# 	 Qid: 3734715
# 	 Q: Refreshed, energized, or exhilarated.
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3479782 TEXT
# 3479783 RADIO
# 	 Qid: 3734716
# 	 Q: An extraordinary feeling of welcoming or being welcomed.
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3479784 RADIO
# 	 Qid: 3734717
# 	 Q: An exceptional sense of closeness appear.
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3479785 TEXT
# 3479786 RADIO
# 	 Qid: 3734718
# 	 Q: I had positive feelings.
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3479787 RADIO
# 	 Qid: 3734719
# 	 Q: I had negative feelings.
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3479788 RADIO
# 	 Qid: 3734720
# 	 Q: I was tense.
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3479789 RADIO
# 	 Qid: 3734721
# 	 Q: I was relaxed.
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3479790 RADIO
# 	 Qid: 3734722
# 	 Q: I felt completely alone.
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3479791 RADIO
# 	 Qid: 3734723
# 	 Q: I was untouched and indifferent.
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3479792 TEXT
# 3479793 RADIO
# 	 Qid: 3734724
# 	 Q: I was moved.
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3479794 RADIO
# 	 Qid: 3734725
# 	 Q: I was touched.
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3479795 RADIO
# 	 Qid: 3734726
# 	 Q: I was full of admiration and wonder.
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3479796 TEXT
# 3483958 RADIO
# 	 Qid: 3739803
# 	 Q: I felt that I was in the presence of something grand.
# 	 	1 (Strongly Disagree)
# 	 	2 (Moderately Disagree)
# 	 	3 (Somewhat Disagree)
# 	 	4 (Neutral)
# 	 	5 (Somewhat Agree)
# 	 	6 (Moderately Agree)
# 	 	7 (Strongly Agree)
# 3483959 RADIO
# 	 Qid: 3739804
# 	 Q: I experienced something greater than myself.
# 	 	1 (Strongly Disagree)
# 	 	2 (Moderately Disagree)
# 	 	3 (Somewhat Disagree)
# 	 	4 (Neutral)
# 	 	5 (Somewhat Agree)
# 	 	6 (Moderately Agree)
# 	 	7 (Strongly Agree)
# 3483960 RADIO
# 	 Qid: 3739805
# 	 Q: I felt my jaw drop.
# 	 	1 (Strongly Disagree)
# 	 	2 (Moderately Disagree)
# 	 	3 (Somewhat Disagree)
# 	 	4 (Neutral)
# 	 	5 (Somewhat Agree)
# 	 	6 (Moderately Agree)
# 	 	7 (Strongly Agree)
# 3483961 RADIO
# 	 Qid: 3739806
# 	 Q: I gasped.
# 	 	1 (Strongly Disagree)
# 	 	2 (Moderately Disagree)
# 	 	3 (Somewhat Disagree)
# 	 	4 (Neutral)
# 	 	5 (Somewhat Agree)
# 	 	6 (Moderately Agree)
# 	 	7 (Strongly Agree)
# 3483962 RADIO
# 	 Qid: 3739807
# 	 Q: I felt challenged to mentally process what I was experiencing.
# 	 	1 (Strongly Disagree)
# 	 	2 (Moderately Disagree)
# 	 	3 (Somewhat Disagree)
# 	 	4 (Neutral)
# 	 	5 (Somewhat Agree)
# 	 	6 (Moderately Agree)
# 	 	7 (Strongly Agree)
# 3483963 RADIO
# 	 Qid: 3739808
# 	 Q: I found it hard to comprehend the experience in full.
# 	 	1 (Strongly Disagree)
# 	 	2 (Moderately Disagree)
# 	 	3 (Somewhat Disagree)
# 	 	4 (Neutral)
# 	 	5 (Somewhat Agree)
# 	 	6 (Moderately Agree)
# 	 	7 (Strongly Agree)
# 3483964 TEXT
# 3483965 RADIO
# 	 Qid: 3739809
# 	 Q: To what extent do you believe audience members around you were moved?
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3483966 RADIO
# 	 Qid: 3739810
# 	 Q: To what extent did you feel connected to the musicians?
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3483967 RADIO
# 	 Qid: 3739811
# 	 Q: To what extent did you feel connected to the other audience members who were also streaming?
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3483968 RADIO
# 	 Qid: 3739812
# 	 Q: To what extent did you feel connected to the audience members who were physically attending the concert?
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3483969 RADIO
# 	 Qid: 3739813
# 	 Q: How much did you enjoy the piece?
# 	 	0 (I didn’t enjoy it at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (I enjoyed it very much)
# 3484209 RADIO
# 	 Qid: 3740037
# 	 Q: Were you familiar with the music that you heard?
# 	 	0 (I have never heard it before)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (I am very familiar with the music)
# 3484210 RADIO
# 	 Qid: 3740038
# 	 Q: To what extent were you absorbed in your own world?
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3484211 RADIO
# 	 Qid: 3740039
# 	 Q: To what extent were you absorbed by the music?
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3484212 RADIO
# 	 Qid: 3740040
# 	 Q: To what extent did you daydream?
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3484213 RADIO
# 	 Qid: 3740041
# 	 Q: To what extent did you lose your sense of time?
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3484214 RADIO
# 	 Qid: 3740042
# 	 Q: To what extent were you distracted by thoughts or worries of a personal nature?
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3484215 RADIO
# 	 Qid: 3740043
# 	 Q: To what extent were you attentive to the music without distracting thoughts, memories or fantasies?
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3484216 RADIO
# 	 Qid: 3740044
# 	 Q: To what extent did you pay attention to other audience members?
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3484217 RADIO
# 	 Qid: 3740045
# 	 Q: To what extent did you pay attention to yourself and your physical sensations?
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3484218 RADIO
# 	 Qid: 3740046
# 	 Q: To what extent do you feel positively transformed by the music?
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3484219 RADIO
# 	 Qid: 3740047
# 	 Q: To what extent do you feel negatively transformed by the music?
# 	 	0 (Not at all)
# 	 	1
# 	 	2
# 	 	3
# 	 	4
# 	 	5
# 	 	6 (a lot)
# 3484220 RADIO
# 	 Qid: 3740048
# 	 Q: Were you aware of your physical body during this piece?
# 	 	Not at all
# 	 	Rarely
# 	 	Intermittently
# 	 	Continuously
# 3484221 RADIO
# 	 Qid: 3740049
# 	 Q: Were you aware of your own physical movement during this piece? If so, how much did you move relative to your own usual behaviour at this kind of concert?
# 	 	Not aware of movement
# 	 	Yes and I moved less than usual
# 	 	Yes and I moved a normal amount
# 	 	Yes and I moved more than usual
# 3484222 RADIO
# 	 Qid: 3740050
# 	 Q: Were you aware of others in the audience moving during the piece? If so, how much were they moving relative to the usual behaviour you observe at this kind of concert?
# 	 	Not aware of others&#39; movement
# 	 	Yes and they moved less than usual
# 	 	Yes and they moved a normal amount
# 	 	Yes and they moved more than usual

# %%
formID = formes[4]
request_url = 'https://nettskjema.no/api/v2/forms/' + str(formID) + '/submissions?fromSubmissionId=1'
response = session.get(request_url)
subIDs = json.loads(response.content.decode())#eval(response.content.decode())
print(len(subIDs))
if len(subIDs)<5:
    print(subIDs)
else:
    print(subIDs[0])
# Out:
# 44
# {'submissionId': 16662012, 'createdDate': '2021-10-26T00:00:00.000+0200', 'modifiedDate': '2021-10-26T00:00:00.000+0200', 'delivered': True, 'answerTime': 0, 'answers': [{'answerId': 102693987, 'questionId': 3740041, 'answerOptions': [{'answerOptionId': 8635171, 'sequence': 6, 'text': '5', 'preselected': False, 'correct': False}]}, {'answerId': 102694016, 'questionId': 3739808, 'answerOptions': [{'answerOptionId': 8634665, 'sequence': 5, 'text': '5 (Somewhat Agree)', 'preselected': False, 'correct': False}]}, {'answerId': 102694000, 'questionId': 3734724, 'answerOptions': [{'answerOptionId': 8625812, 'sequence': 3, 'text': '2', 'preselected': False, 'correct': False}]}, {'answerId': 102694020, 'questionId': 3740046, 'answerOptions': [{'answerOptionId': 8635205, 'sequence': 5, 'text': '4', 'preselected': False, 'correct': False}]}, {'answerId': 102694018, 'questionId': 3734713, 'answerOptions': [{'answerOptionId': 8625733, 'sequence': 1, 'text': '0 (Not at all)', 'preselected': False, 'correct': False}]}, {'answerId': 102693985, 'questionId': 3734726, 'answerOptions': [{'answerOptionId': 8625824, 'sequence': 1, 'text': '0 (Not at all)', 'preselected': False, 'correct': False}]}, {'answerId': 102693992, 'questionId': 3740047, 'answerOptions': [{'answerOptionId': 8635208, 'sequence': 1, 'text': '0 (Not at all)', 'preselected': False, 'correct': False}]}, {'answerId': 102693997, 'questionId': 3740343, 'textAnswer': '09d8163d-80e7-fda3-6919-6a3febc78e27'}, {'answerId': 102694023, 'questionId': 3740037, 'answerOptions': [{'answerOptionId': 8635144, 'sequence': 7, 'text': '6 (I am very familiar with the music)', 'preselected': False, 'correct': False}]}, {'answerId': 102693988, 'questionId': 3734719, 'answerOptions': [{'answerOptionId': 8625775, 'sequence': 1, 'text': '0 (Not at all)', 'preselected': False, 'correct': False}]}, {'answerId': 102694014, 'questionId': 3734725, 'answerOptions': [{'answerOptionId': 8625817, 'sequence': 1, 'text': '0 (Not at all)', 'preselected': False, 'correct': False}]}, {'answerId': 102694012, 'questionId': 3734722, 'answerOptions': [{'answerOptionId': 8625799, 'sequence': 4, 'text': '3', 'preselected': False, 'correct': False}]}, {'answerId': 102693993, 'questionId': 3734723, 'answerOptions': [{'answerOptionId': 8625806, 'sequence': 4, 'text': '3', 'preselected': False, 'correct': False}]}, {'answerId': 102694025, 'questionId': 3739805, 'answerOptions': [{'answerOptionId': 8634643, 'sequence': 4, 'text': '4 (Neutral)', 'preselected': False, 'correct': False}]}, {'answerId': 102693998, 'questionId': 3734720, 'answerOptions': [{'answerOptionId': 8625783, 'sequence': 2, 'text': '1', 'preselected': False, 'correct': False}]}, {'answerId': 102693994, 'questionId': 3739811, 'answerOptions': [{'answerOptionId': 8634684, 'sequence': 3, 'text': '2', 'preselected': False, 'correct': False}]}, {'answerId': 102694007, 'questionId': 3734718, 'answerOptions': [{'answerOptionId': 8625772, 'sequence': 5, 'text': '4', 'preselected': False, 'correct': False}]}, {'answerId': 102694003, 'questionId': 3740038, 'answerOptions': [{'answerOptionId': 8635147, 'sequence': 3, 'text': '2', 'preselected': False, 'correct': False}]}, {'answerId': 102694011, 'questionId': 3740045, 'answerOptions': [{'answerOptionId': 8635197, 'sequence': 4, 'text': '3', 'preselected': False, 'correct': False}]}, {'answerId': 102693995, 'questionId': 3734715, 'answerOptions': [{'answerOptionId': 8625750, 'sequence': 4, 'text': '3', 'preselected': False, 'correct': False}]}, {'answerId': 102694009, 'questionId': 3739812, 'answerOptions': [{'answerOptionId': 8634691, 'sequence': 3, 'text': '2', 'preselected': False, 'correct': False}]}, {'answerId': 102694019, 'questionId': 3740039, 'answerOptions': [{'answerOptionId': 8635156, 'sequence': 5, 'text': '4', 'preselected': False, 'correct': False}]}, {'answerId': 102693999, 'questionId': 3739806, 'answerOptions': [{'answerOptionId': 8634650, 'sequence': 4, 'text': '4 (Neutral)', 'preselected': False, 'co ...

# %%
import pandas

# %% [markdown]
# # old notes
# Username
# Short description
# Personal owners
# Last active
#
# finnuritmo @ api
#
# finnuritmo @ api
#
# New token created
# Token: dar7qsem18ljlqc0ntg8ivbble69nf0g26n8177pk1hlskstanj3gfu78se8q12pro889535p9quqi78akr4hhajijnkj6l0b79aflgdgehlb0ht50870ggkm9t5rnk6fr86
# Save the token as it is not stored in the Web form.
#
# The token can be used for the following API calls:
# WRITE_FORMS
# WRITE_INVITATIONS
# READ_SUBMISSIONS
# READ_INVITATIONS
# READ_FORMS
# Allowed IP addresses : 129.240.0.0/16, 193.157.0.0/16
#
# 193.157.119.236
#
# https://nettskjema.no/user/api/index.html
#
# https://lcbc-uio.github.io/nettskjemar/articles/auth_setup.html
#
# https://realpython.com/api-integration-in-python/#rest-and-python-consuming-apis
#
# https://docs.python-requests.org/en/latest/user/authentication/
#
#
#
# https://nettskjema.no/a/141510
#
#
# $ curl 'https://nettskjema.no/api/v2/submissions/5136791' -i -X GET \
#     -H 'Authorization: Bearer TOKEN'
#
#
# curl 'https://nettskjema.no/api/v2/users/admin/tokens/expire-date' -i -X GET \ -H 'Authorization: Bearer TOKEN'
#
#
#
# $ curl 'https://nettskjema.no/api/v2/submissions/141510' -i -X GET -H 'Authorization: finnuritmo @ api TOKEN'
#
#
# curl 'https://nettskjema.no/api/v2/users/admin/tokens/expire-date' -i -X GET \ -H 'Authorization: Bearer TOKEN'
#
#
#
#
#
# *******
# base64 --decode customname1.txt > datazip.zip
#
# base64 0c6a885b-de29-a128-1480-fe98e4a06f69.geoLocation.csv  > output.txt
#
# /Desktop/Current_Projects/Resp_Mobile_recording/DataJockying/data(8).zip
